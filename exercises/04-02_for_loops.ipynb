# %% [markdown]
# # Let's Discover For Loops in Python!
#
# Hey there! 🌈 Ready to explore another cool part of coding? Today we're going to talk about "for loops" in Python. They're like a magic spell for repeating stuff in your code!
#
# ## What's a Loop?
#
# First, let's remember what a loop is. Imagine you're jumping on a trampoline. Each jump is like one loop. Now, what if you decide to jump exactly 10 times? That's where a for loop comes in handy!
#
# ## For Loops: The Basics
#
# A "for loop" is a way to repeat an action a certain number of times. It's like saying, "Hey Python, do this thing these many times."
#
# ## The Syntax of a For Loop
#
# Here's how you write a for loop in Python:

# %%
for i in range(10):
    print("I'm jumping on a trampoline! "+str(i))

# %% [markdown]
# 1) **`for i in range(10)`:** This line sets up a loop that will run 10 times.
#    `range(10)` creates a sequence of numbers from 0 to 9.
#
# 2) **`i`:** In each loop, `i` takes on the next number in the sequence created
#    by `range(10)`. First, `i` is 0, then 1, then 2, and so on, up to 9.
#
# 3) **`print("I'm jumping on a trampoline! " + str(i))`:** Each time the loop
#    runs, this line prints out a message. The `str(i)` part converts the number
#    `i` into a string so it can be added to the text. So, you'll see "I'm jumping
#    on a trampoline! 0", then "I'm jumping on a trampoline! 1", and so on, up to
#    "I'm jumping on a trampoline! 9".
#
# In summary, `i` changes with each loop, counting up from 0 to 9, and each time,
# it's included in the message that's printed out. It's like having a counter that
# keeps track of how many jumps you've made on the trampoline! 🌟🤸‍♂️🔄
#
# ## Using For Loops with range()
#
# The `range()` function is super handy with for loops. It's like setting the
# number of jumps on a trampoline. For example, if you write `range(5)`, it's like
# planning to do 5 jumps.
#
# The `range()` function creates a series of numbers:
#
# - **`range(5)`**: This creates a series of numbers from 0 to 4. It's important
#   to remember that the counting starts at 0 and goes up to, but does not
#   include, the specified value. So, it ends at 4.
#
# - **`range(1, 5)`**: This creates a series of numbers from 1 to 4. Here, the
#   counting starts at 1 (the first value) and goes up to, but not including, 5
#   (the second value). So, it stops at 4.
#
# - **`range(1, 11, 2)`**: This creates a series of every other number from 1 to
#   10. The counting starts at 1 (the first value), goes up to, but not including,
#   11 (the second value), and skips every second number (as specified by the
#   third value). So, you get 1, 3, 5, 7, 9.
#
# ### Example Time!
#
# Let's say you want to count from 1 to 5. Here's how you'd do it:

# %%
for number in range(1, 6):
    print(number)

# %% [markdown]
# This loop will print the numbers 1, 2, 3, 4, and 5. We started at 1 and went up
# to (but not including) 6.
#
# ### Try it out
#
# Modify the code below so that it prints out every 3rd number between 1 and 20.
# For example, it should print the numbers 1, 4, 7, 10, 13, 16, and 19.

# %%
for number in range(1, 6):
    print(number)

# %% [markdown]
# ## In a Nutshell
#
# For loops are great for when you know exactly how many times you want to repeat
# something. They're like your personal repeat button in coding. So, the next time
# you want to do something over and over, just set up a for loop and let it work
# its magic! 🔄🔮💻
#
# ---

# %% [markdown]
# ## Challenge 1
#
# ![challenge 1 image](./images/04/1.png)
#
# Do you recall the challenge we tackled in our first learning module? Let's solve
# it again, but this time, instead of copying and pasting the same commands over
# and over, we'll use a `for` loop to make things easier and more efficient.
#
# **To Do**
#
# Add a `for` loop with the `range()` function to the code below. This loop will
# help you draw the shape we learned about earlier.
#
# **Hint**
#
# - Revisit your solution from the first lesson's challenge. Notice which lines of
#   code are the same and repeat. Now, include those repeated lines inside the
#   `for` loop.
#
# - The solution only requires you to add a single line of code!
#
# - There are 4 sides to the shape so your `for` loop will only need to run 4 times.

# %%
from ipyturtle import Turtle

t = Turtle()

t.forward(100)
t.left(90)

# %% [markdown]
# <style>
#   .container {
#     border: 1px solid black;
#     padding: 10px;
#     cursor: pointer;
#     overflow: hidden;
#     transition: max-height 1s ease-in-out;
#     max-width:400px;
#   }
#   .fade {
#     transition: opacity 1s ease-in-out;
#     opacity: 0;
#     pointer-events: none;
#     max-height: 0;
#     white-space: pre;
#   }
#   .fade-in {
#     opacity: 1;
#     pointer-events: auto;
#     max-height: 500px; /* Use an arbitrary large height to accommodate the content */
#   }
# </style>
#
# <div class="container"
#      onmouseover="this.querySelector('.answer').classList.add('fade-in'); this.querySelector('.prompt').classList.remove('fade-in');"
#      onmouseout="this.querySelector('.answer').classList.remove('fade-in'); this.querySelector('.prompt').classList.add('fade-in');">
#     <span class="prompt fade-in">Show answer</span>
#     <div class="answer fade">
#
# <pre>
# from ipyturtle import Turtle
#
# t = Turtle()
#
# for i in range(4):
#     t.forward(100)
#     t.left(90)
# </pre>
#
#   </div>
# </div>

# %% [markdown]
# ## Challenge 2
#
# ![challenge 2 image](./images/04/2.png)
#
# Remember the fun challenge from our first lesson? Let's take another crack at
# it. But now, instead of repeating commands by copy-pasting them, we're going to
# use a `for` loop. It's a smarter way to get the job done without all that
# repetition.
#
# **To Do**
#
# Put a `for` loop using the `range()` function in the code below. It's going to
# help you draw that triangle above.
#
# **Hint**
#
# - Revisit your solution from the first lesson's challenge. Notice which lines of
#   code are the same and repeat. Now, include those repeated lines inside the
#   `for` loop.
#
# - You only need to add one line of code to find the solution!
#
# - There are 3 sides to the shape so your `for` loop will only need to run 3
#   times.

# %%
from ipyturtle import Turtle

t = Turtle()

t.forward(100)
t.left(120)

# %% [markdown]
# <style>
#   .container {
#     border: 1px solid black;
#     padding: 10px;
#     cursor: pointer;
#     overflow: hidden;
#     transition: max-height 1s ease-in-out;
#     max-width:400px;
#   }
#   .fade {
#     transition: opacity 1s ease-in-out;
#     opacity: 0;
#     pointer-events: none;
#     max-height: 0;
#     white-space: pre;
#   }
#   .fade-in {
#     opacity: 1;
#     pointer-events: auto;
#     max-height: 500px; /* Use an arbitrary large height to accommodate the content */
#   }
# </style>
#
# <div class="container"
#      onmouseover="this.querySelector('.answer').classList.add('fade-in'); this.querySelector('.prompt').classList.remove('fade-in');"
#      onmouseout="this.querySelector('.answer').classList.remove('fade-in'); this.querySelector('.prompt').classList.add('fade-in');">
#     <span class="prompt fade-in">Show answer</span>
#     <div class="answer fade">
#
# <pre>
# from ipyturtle import Turtle
#
# t = Turtle()
#
# for i in range(3):
#     t.forward(100)
#     t.left(120)
# </pre>
#
#   </div>
# </div>

# %% [markdown]
# ## Challenge 3
#
# ![challenge 2 image](./images/04/3.png)
#
# **To Do**
#
# Put a `for` loop using the `range()` function in the code below. It's going to
# help you draw that cool shape we saw before.

# %%
from ipyturtle import Turtle

t = Turtle()

t.forward(50)
t.left(45)

# %% [markdown]
# <style>
#   .container {
#     border: 1px solid black;
#     padding: 10px;
#     cursor: pointer;
#     overflow: hidden;
#     transition: max-height 1s ease-in-out;
#     max-width:400px;
#   }
#   .fade {
#     transition: opacity 1s ease-in-out;
#     opacity: 0;
#     pointer-events: none;
#     max-height: 0;
#     white-space: pre;
#   }
#   .fade-in {
#     opacity: 1;
#     pointer-events: auto;
#     max-height: 500px; /* Use an arbitrary large height to accommodate the content */
#   }
# </style>
#
# <div class="container"
#      onmouseover="this.querySelector('.answer').classList.add('fade-in'); this.querySelector('.prompt').classList.remove('fade-in');"
#      onmouseout="this.querySelector('.answer').classList.remove('fade-in'); this.querySelector('.prompt').classList.add('fade-in');">
#     <span class="prompt fade-in">Show answer</span>
#     <div class="answer fade">
#
# <pre>
# from ipyturtle import Turtle
#
# t = Turtle()
#
# for i in range(8):
#     t.forward(50)
#     t.left(45)
# </pre>
#
#   </div>
# </div>

# %% [markdown]
# ## Challenge 4 (Bonus)
#
# ![challenge 2 image](./images/04/4.png)
#
# Did you know you can put a `for` loop inside a `for` loop? Check it out!
#
# Putting a `for` loop inside another `for` loop is called a "nested loop." It's like having a loop within a loop, and it's super useful for certain tasks. Let me explain a bit more:
#
# Imagine you're organizing a small race for each grade in your school. You could use one `for` loop to go through each grade, and inside that loop, you could have another `for` loop to handle each student in that grade. It's like looping through the grades, and for each grade, looping through its students.
#
# Here's a simple example:

# %%
for grade in range(1, 4):  # Loop through grades 1 to 3
    for student in range(1, 11):  # Loop through 10 students in each grade
        print(f"Grade {grade}, Student {student}")

# %% [markdown]
# This code will print out a list for students in grades 1, 2, and 3, counting up to 10 students in each grade.
#
# Nested loops are a powerful tool in coding, especially when you're dealing with things that are organized in rows and columns, like grids or tables! 🔄🏫👩‍🏫👨‍🏫

# %% [markdown]
# **To Do**
#
# Create the image shown above by adding a nested `for` loop using the `range()` function in the code below.
#
# **Hint**
#
# - Begin by focusing on drawing just one square. Refer to your solution from
#   Challenge 1 if you need help.
#
# - Then, place the loop that draws a square inside another `for` loop. This
#   creates a nested loop, allowing you to repeatedly draw the square.
#
# - Finally, adjust the value in the `forward()` command so it corresponds to an
#   increasing number in the outer `for` loop.

# %%
from ipyturtle import Turtle

t = Turtle()

t.forward(100)
t.left(90)

# %% [markdown]
# <style>
#   .container {
#     border: 1px solid black;
#     padding: 10px;
#     cursor: pointer;
#     overflow: hidden;
#     transition: max-height 1s ease-in-out;
#     max-width:400px;
#   }
#   .fade {
#     transition: opacity 1s ease-in-out;
#     opacity: 0;
#     pointer-events: none;
#     max-height: 0;
#     white-space: pre;
#   }
#   .fade-in {
#     opacity: 1;
#     pointer-events: auto;
#     max-height: 500px; /* Use an arbitrary large height to accommodate the content */
#   }
# </style>
#
# <div class="container"
#      onmouseover="this.querySelector('.answer').classList.add('fade-in'); this.querySelector('.prompt').classList.remove('fade-in');"
#      onmouseout="this.querySelector('.answer').classList.remove('fade-in'); this.querySelector('.prompt').classList.add('fade-in');">
#     <span class="prompt fade-in">Show answer</span>
#     <div class="answer fade">
#
# <pre>
# from ipyturtle import Turtle
#
# t = Turtle()
#
# for steps in range(100, 160, 20):
#     for i in range(4):
#         t.forward(steps)
#         t.left(90)
# </pre>
#
#   </div>
# </div>
